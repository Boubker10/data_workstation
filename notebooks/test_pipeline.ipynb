# %%
import sys
sys.path.append("..")  
from src.project.main import fit_transform

data = fit_transform(None)

# %%
data.head()
# Out:
#    store        date  Weekly_Sales  weekly_sales_diff  \
# 0      1  01-04-2011    1495064.75               0.00
# 1      1  01-06-2012    1624477.58          129412.83
# 2      1  01-07-2011    1488538.09         -135939.49
# 3      1  01-10-2010    1453329.50          -35208.59
# 4      1  02-03-2012    1688420.76          235091.26
#
#    weekly_sales_pct_change Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0                 0.000000            0        59.17       3.524  214.837166
# 1                 0.086560            0        77.95       3.501  221.747214
# 2                -0.083682            0        85.55       3.524  215.184137
# 3                -0.023653            0        71.89       2.603  211.671989
# 4                 0.161760            0        60.96       3.630  220.848045
#
#    Unemployment  ... fuel_price_x_unemployment cpi_x_unemployment  \
# 0         7.682  ...                 27.071368        1650.379112
# ...
